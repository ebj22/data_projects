# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
braz_url = "https://brazil-help.com/brazilian_states.htm"

response_braz = requests.get(braz_url)

soup_braz = BeautifulSoup(response_braz.content, 'html.parser')

# %%
print(soup_braz.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html public "-//w3c//dtd html 4.0 transitional//en">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Brazilian states, abbreviations, states, Brazilian, Brasil, regions, areas, capitols, city, populations, demographics, sizes, flags, peoples, inhabitants, populations, per capita incomes, square kilometers, maps, life expectancy, area codes, zip codes, CEPs, federal district" name="description"/>
# ...

# %%
soup_braz.find_all(class_="MsoNormalTable")[2].find_all("tr")[1].find_all("td")[0].find("center").get_text()
# Out:
# 'Common\nTwo Letter\nAbbreviation'

# %%
list1 = [None] * 10 

for x in range(10):
  list1[x] = list()

for i in range(29):
  for y in range(10):
    list1[y].append(
        soup_braz.find_all(class_="MsoNormalTable")[2].find_all("tr")[i].find_all("td")[y].find("center").get_text()
    )

for a in range(10):
  print(list1[a])
# Out:
# ['BR', 'Common\nTwo Letter\nAbbreviation', 'AC', 'AL', 'AP', 'AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MT', 'MS', 'MG', 'PA', 'PB', 'PR', 'PE', 'PI', 'RJ', 'RN', 'RS', 'RO', 'RR', 'SC', 'SP', 'SE', 'TO']
# ['Brazil\n(entire country)', 'State', 'Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito\nFederal', 'Espírito\nSanto', 'Goiás', 'Maranhão', 'MatoGrosso', 'MatoGrosso\ndo Sul', 'Minas\nGerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio\nde Janeiro', 'Rio\nGrande do Norte', 'Rio\nGrande do Sul', 'Rondônia', 'Roraima', 'Santa\nCatarina', 'São\nPaulo', 'Sergipe', 'Tocantins']
# ['Brasília', 'Capitol\nCity', 'Rio Branco', 'Maceió', 'Macapá', 'Manaus', 'Salvador', 'Fortaleza', 'Brasília', 'Vitória', 'Goiânia', 'São\nLuís', 'Cuiabá', 'Campo Grande', 'Belo Horizonte', 'Belém', 'João\nPessoa', 'Curitiba', 'Recife', 'Teresina', 'Rio de Janeiro', 'Natal', 'Porto Alegre', 'Porto Velho', 'Boa Vista', 'Florianópolis', 'São\nPaulo', 'Aracajú', 'Palmas']
# ...

# %%
dict1 = {}
for x in range(10):
  if x == 0:
    a = list1[x].pop(1)
    dict1.update({a: list1[x]})
  elif x == 1:
    b = list1[x].pop(1)
    dict1.update({b: list1[x]})
  elif x == 2:
    c = list1[x].pop(1)
    dict1.update({c: list1[x]})
  elif x == 3:
    d = list1[x].pop(1)
    dict1.update({d: list1[x]})
  elif x == 4:
    e = list1[x].pop(1)
    dict1.update({e: list1[x]})
  elif x == 5:
    f = list1[x].pop(1)
    dict1.update({f: list1[x]})
  elif x == 6:
    g = list1[x].pop(1)
    dict1.update({g: list1[x]})
  elif x == 7:
    h = list1[x].pop(1)
    dict1.update({h: list1[x]})
  elif x == 8:
    i = list1[x].pop(1)
    dict1.update({i: list1[x]})
  elif x == 9:
    j = list1[x].pop(1)
    dict1.update({j: list1[x]})




print(dict1)
# Out:
# {'Common\nTwo Letter\nAbbreviation': ['BR', 'AC', 'AL', 'AP', 'AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MT', 'MS', 'MG', 'PA', 'PB', 'PR', 'PE', 'PI', 'RJ', 'RN', 'RS', 'RO', 'RR', 'SC', 'SP', 'SE', 'TO'], 'State': ['Brazil\n(entire country)', 'Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito\nFederal', 'Espírito\nSanto', 'Goiás', 'Maranhão', 'MatoGrosso', 'MatoGrosso\ndo Sul', 'Minas\nGerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio\nde Janeiro', 'Rio\nGrande do Norte', 'Rio\nGrande do Sul', 'Rondônia', 'Roraima', 'Santa\nCatarina', 'São\nPaulo', 'Sergipe', 'Tocantins'], 'Capitol\nCity': ['Brasília', 'Rio Branco', 'Maceió', 'Macapá', 'Manaus', 'Salvador', 'Fortaleza', 'Brasília', 'Vitória', 'Goiânia', 'São\nLuís', 'Cuiabá', 'Campo Grande', 'Belo Horizonte', 'Belém', 'João\nPessoa', 'Curitiba', 'Recife', 'Teresina', 'Rio de Janeiro', 'Natal', 'Porto Alegre', 'Porto Velho', 'Boa Vista', 'Florianópolis', 'São\nPaulo', 'Aracajú', 'Palmas'], 'Region': 
# ...

# %%
for y in dict1:
    print(y, ":",dict1[y])
# Out:
# Common
# Two Letter
# Abbreviation : ['BR', 'AC', 'AL', 'AP', 'AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MT', 'MS', 'MG', 'PA', 'PB', 'PR', 'PE', 'PI', 'RJ', 'RN', 'RS', 'RO', 'RR', 'SC', 'SP', 'SE', 'TO']
# State : ['Brazil\n(entire country)', 'Acre', 'Alagoas', 'Amapá', 'Amazonas', 'Bahia', 'Ceará', 'Distrito\nFederal', 'Espírito\nSanto', 'Goiás', 'Maranhão', 'MatoGrosso', 'MatoGrosso\ndo Sul', 'Minas\nGerais', 'Pará', 'Paraíba', 'Paraná', 'Pernambuco', 'Piauí', 'Rio\nde Janeiro', 'Rio\nGrande do Norte', 'Rio\nGrande do Sul', 'Rondônia', 'Roraima', 'Santa\nCatarina', 'São\nPaulo', 'Sergipe', 'Tocantins']
# Capitol
# City : ['Brasília', 'Rio Branco', 'Maceió', 'Macapá', 'Manaus', 'Salvador', 'Fortaleza', 'Brasília', 'Vitória', 'Goiânia', 'São\nLuís', 'Cuiabá', 'Campo Grande', 'Belo Horizonte', 'Belém', 'João\nPessoa', 'Curitiba', 'Recife', 'Teresina', 'Rio de Janeiro', 'Natal', 'Porto Alegre', 'Porto Velho', 'Boa Vista', 'Florianópolis', 'São\nPaulo', 'Aracajú', 'Palmas']
# ...

# %%
braz_df = pd.DataFrame(dict1)

# %%
braz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Common
# Two Letter
# Abbreviation     28 non-null     object
#  1   State                              28 non-null     object
#  2   Capitol
# City                       28 non-null     object
#  3   Region                             28 non-null     object
#  4   Size
# (in km²)                      28 non-null     object
#  5   Population
# (2007 estimate)         28 non-null     object
#  6   %
# Pop.
# Urban/Rural                 28 non-null     object
#  7   Number
# of Municipal Districts      28 non-null     object
#  8   Per
# Capita GNP in Reais (R$)       28 non-null     object
#  9   Life
# Expectancy
# (2007 projection)  28 non-null     object
# dtypes: object(10)
# memory usage: 2.3+ KB

# %%
braz_df
# Out:
#    Common\nTwo Letter\nAbbreviation                     State   Capitol\nCity  \
# 0                                BR  Brazil\n(entire country)        Brasília
# 1                                AC                      Acre      Rio Branco
# 2                                AL                   Alagoas          Maceió
# 3                                AP                     Amapá          Macapá
# 4                                AM                  Amazonas          Manaus
# 5                                BA                     Bahia        Salvador
# 6                                CE                     Ceará       Fortaleza
# 7                                DF         Distrito\nFederal        Brasília
# 8                                ES           Espírito\nSanto         Vitória
# 9                                GO                     Goiás         Goiânia
# 10                               MA                  Maranhão       São\nLuís
# ...

# %%
braz_df2 = braz_df.copy()

# %%
listd = []
for t in dict1:
    listd.append(t)
print(listd)
# Out:
# ['Common\nTwo Letter\nAbbreviation', 'State', 'Capitol\nCity', 'Region', 'Size\n(in km²)', 'Population\n(2007 estimate)', '%\nPop.\nUrban/Rural', 'Number\nof Municipal Districts', 'Per\nCapita GNP in Reais (R$)', 'Life\nExpectancy\n(2007 projection)']

# %%
listd
# Out:
# ['Common\nTwo Letter\nAbbreviation',
#  'State',
#  'Capitol\nCity',
#  'Region',
#  'Size\n(in km²)',
#  'Population\n(2007 estimate)',
#  '%\nPop.\nUrban/Rural',
#  'Number\nof Municipal Districts',
#  'Per\nCapita GNP in Reais (R$)',
#  'Life\nExpectancy\n(2007 projection)']

# %%
listd2 = listd.copy()

# %%
import re

# %%
# for l in range(len(listd)):
#     listd2[l] = listd2[l].replace("\n", " ")

for l in range(len(listd)):
    listd2[l] = listd2[l].replace("\n", "_")
    listd2[l] = listd2[l].replace("(", "")
    listd2[l] = listd2[l].replace(")", "")
    listd2[l] = listd2[l].replace(" ", "_")

# %%
listd2
# Out:
# ['Common_Two_Letter_Abbreviation',
#  'State',
#  'Capitol_City',
#  'Region',
#  'Size_in_km²',
#  'Population_2007_estimate',
#  '%_Pop._Urban/Rural',
#  'Number_of_Municipal_Districts',
#  'Per_Capita_GNP_in_Reais_R$',
#  'Life_Expectancy_2007_projection']

# %%
dict2 = {}
for x in range(10):
  if x == 0:
    dict2.update({listd[x]: listd2[x]})
  elif x == 2:
    dict2.update({listd[x]: listd2[x]})
  elif x == 2:
    dict2.update({listd[x]: listd2[x]})
  elif x == 3:
    dict2.update({listd[x]: listd2[x]})
  elif x == 4:
    dict2.update({listd[x]: listd2[x]})
  elif x == 5:
    dict2.update({listd[x]: listd2[x]})
  elif x == 6:
    dict2.update({listd[x]: listd2[x]})
  elif x == 7:
    dict2.update({listd[x]: listd2[x]})
  elif x == 8:
    dict2.update({listd[x]: listd2[x]})
  elif x == 9:
    dict2.update({listd[x]: listd2[x]})

# %%
dict2
# Out:
# {'Common\nTwo Letter\nAbbreviation': 'Common_Two_Letter_Abbreviation',
#  'Capitol\nCity': 'Capitol_City',
#  'Region': 'Region',
#  'Size\n(in km²)': 'Size_in_km²',
#  'Population\n(2007 estimate)': 'Population_2007_estimate',
#  '%\nPop.\nUrban/Rural': '%_Pop._Urban/Rural',
#  'Number\nof Municipal Districts': 'Number_of_Municipal_Districts',
#  'Per\nCapita GNP in Reais (R$)': 'Per_Capita_GNP_in_Reais_R$',
#  'Life\nExpectancy\n(2007 projection)': 'Life_Expectancy_2007_projection'}

# %%
braz_df2 = braz_df2.rename( columns = dict2)

# %%
braz_df2
# Out:
#    Common_Two_Letter_Abbreviation                     State    Capitol_City  \
# 0                              BR  Brazil\n(entire country)        Brasília
# 1                              AC                      Acre      Rio Branco
# 2                              AL                   Alagoas          Maceió
# 3                              AP                     Amapá          Macapá
# 4                              AM                  Amazonas          Manaus
# 5                              BA                     Bahia        Salvador
# 6                              CE                     Ceará       Fortaleza
# 7                              DF         Distrito\nFederal        Brasília
# 8                              ES           Espírito\nSanto         Vitória
# 9                              GO                     Goiás         Goiânia
# 10                             MA                  Maranhão       São\nLuís
# ...

# %%
for g in range(len(listd2)):
  braz_df2[listd2[g]] = braz_df2[listd2[g]].str.replace("\n", " ")

# %%
braz_df2
# Out:
#    Common_Two_Letter_Abbreviation                    State    Capitol_City  \
# 0                              BR  Brazil (entire country)        Brasília
# 1                              AC                     Acre      Rio Branco
# 2                              AL                  Alagoas          Maceió
# 3                              AP                    Amapá          Macapá
# 4                              AM                 Amazonas          Manaus
# 5                              BA                    Bahia        Salvador
# 6                              CE                    Ceará       Fortaleza
# 7                              DF         Distrito Federal        Brasília
# 8                              ES           Espírito Santo         Vitória
# 9                              GO                    Goiás         Goiânia
# 10                             MA                 Maranhão        São Luís
# ...

# %%
braz_sql_df = braz_df2.copy()

# %%
# dict3 = {}
# for x in range(10):
#   if x == 0:
#     dict3.update({listd2[x]: "Common_Two_Letter_Abbreviation"})
#   elif x == 1:
#     continue
#   elif x == 2:
#     dict3.update({listd2[x]: "Capital_City"})
#   elif x == 3:
#     continue
#   elif x == 4:
#     dict3.update({listd2[x]: "Size_km_squared"})
#   elif x == 5:
#     dict3.update({listd2[x]: "Population_2007_estimate"})
#   elif x == 6:
#     dict3.update({listd2[x]: "Pop_percent_Urban_Rural"})
#   elif x == 7:
#     dict3.update({listd2[x]: "Number_of_Municipal_Districts"})
#   elif x == 8:
#     dict3.update({listd2[x]: "Per_Capita_GNP_in_Reais_R$"})
#   elif x == 9:
#     dict3.update({listd2[x]: "Life_Expectancy_2007_projection"})

# %%
# braz_sql_df = braz_sql_df.rename( columns = dict3)

# %%
braz_sql_df
# Out:
#    Common_Two_Letter_Abbreviation                    State    Capitol_City  \
# 0                              BR  Brazil (entire country)        Brasília
# 1                              AC                     Acre      Rio Branco
# 2                              AL                  Alagoas          Maceió
# 3                              AP                    Amapá          Macapá
# 4                              AM                 Amazonas          Manaus
# 5                              BA                    Bahia        Salvador
# 6                              CE                    Ceará       Fortaleza
# 7                              DF         Distrito Federal        Brasília
# 8                              ES           Espírito Santo         Vitória
# 9                              GO                    Goiás         Goiânia
# 10                             MA                 Maranhão        São Luís
# ...

# %%
for g in range(len(listd2)):
  if g == 4:
    braz_sql_df[listd2[g]] = braz_sql_df[listd2[g]].str.replace(",", "")
  elif g == 5:
    braz_sql_df[listd2[g]] = braz_sql_df[listd2[g]].str.replace(",", "")
  elif g == 8:
    braz_sql_df[listd2[g]] = braz_sql_df[listd2[g]].str.replace(",", "")
    braz_sql_df[listd2[g]] = braz_sql_df[listd2[g]].str.replace("R$", "")

# %%
braz_sql_df
# Out:
#    Common_Two_Letter_Abbreviation                    State    Capitol_City  \
# 0                              BR  Brazil (entire country)        Brasília
# 1                              AC                     Acre      Rio Branco
# 2                              AL                  Alagoas          Maceió
# 3                              AP                    Amapá          Macapá
# 4                              AM                 Amazonas          Manaus
# 5                              BA                    Bahia        Salvador
# 6                              CE                    Ceará       Fortaleza
# 7                              DF         Distrito Federal        Brasília
# 8                              ES           Espírito Santo         Vitória
# 9                              GO                    Goiás         Goiânia
# 10                             MA                 Maranhão        São Luís
# ...

# %%
schema = "magist"
host = "127.0.0.1"
user = "root"
password = ""
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
braz_sql_df.to_sql("brazil_states", if_exists="append", con = connection_string, index=False)
# Out:
# 28

# %%
# df_from_sql = pd.read_sql("brazil_states", con=connection_string)
# df_from_sql
